# %%
from manim import *
param = "-v WARNING -r 500,200 -s  --disable_caching Example"

# %%
config.background_color = WHITE
Text.set_default(color=BLACK)
Line.set_default(color=YELLOW)
Line.set_default(stroke_width=20)
class Example(ZoomedScene):
    def construct(self):
        # self.camera.background_color = WHITE  # alternative way.
        mob = Text("Light Mode")
        l = Line(2 * LEFT, 2 * RIGHT).next_to(mob, DOWN)
        self.add(mob, l)
        Line.set_default()
        Text.set_default()
        self.camera.frame.scale(1 / 4)

# %manim $param

# %%
class Example(Scene):
    def construct(self):
        m= ManimBanner()
        self.add(m)

# %manim $param
